# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger_eng')


def tokenize_text(text):
    tokens = word_tokenize(text.lower())  # Tokenize the text
    return tokens

def count_word_frequency(tokens):
    word_freq = Counter(tokens)  # Count the frequency of each word
    return word_freq

def remove_stop_words(tokens):
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]  # Remove stop words
    return filtered_tokens

def pos_tagging(tokens):
    tagged_tokens = pos_tag(tokens)  # Perform POS tagging
    return tagged_tokens

# Take input from the user
text = input("Enter a sentence: ")

# Tokenization
tokens = tokenize_text(text)

# Word frequency count
word_freq = count_word_frequency(tokens)

# Removing stop words
filtered_tokens = remove_stop_words(tokens)

# POS tagging
tagged_tokens = pos_tagging(filtered_tokens)

print("Tokens:", tokens)
print("Word Frequency:", word_freq)
print("Filtered Tokens (after stop words removal):", filtered_tokens)
print("POS Tagged Tokens:", tagged_tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\deoka\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\deoka\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\deoka\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# Enter a sentence:  can you help me?
# Tokens: ['can', 'you', 'help', 'me', '?']
# Word Frequency: Counter({'can': 1, 'you': 1, 'help': 1, 'me': 1, '?': 1})
# Filtered Tokens (after stop words removal): ['help', '?']
# POS Tagged Tokens: [('help', 'NN'), ('?', '.')]

# %%
import math

# Board setup
board = [' ' for _ in range(9)]

# Function to print the board
def print_board():
    for row in [board[i*3:(i+1)*3] for i in range(3)]:
        print('| ' + ' | '.join(row) + ' |')

# Check for winner''
def is_winner(brd, player):
    win_conditions = [
        [0, 1, 2], [3, 4, 5], [6, 7, 8],  # rows
        [0, 3, 6], [1, 4, 7], [2, 5, 8],  # columns
        [0, 4, 8], [2, 4, 6]              # diagonals
    ]
    for condition in win_conditions:
        if all(brd[i] == player for i in condition):
            return True
    return False

# Check if board is full
def is_full(brd):
    return ' ' not in brd

# Get available moves
def get_available_moves(brd):
    return [i for i in range(9) if brd[i] == ' ']

# Minimax Algorithm
def minimax(brd, depth, is_maximizing):
    if is_winner(brd, 'O'):
        return 1
    elif is_winner(brd, 'X'):
           return -1
    elif is_full(brd):
        return 0

    if is_maximizing:
        best_score = -math.inf
        for move in get_available_moves(brd):
            brd[move] = 'O'
            score = minimax(brd, depth + 1, False)
            brd[move] = ' '
            best_score = max(score, best_score)
        return best_score
    else:
        best_score = math.inf
        for move in get_available_moves(brd):
            brd[move] = 'X'
            score = minimax(brd, depth + 1, True)
            brd[move] = ' '
            best_score = min(score, best_score)
        return best_score

# AI makes move
def ai_move():
    best_score = -math.inf
    best_move = None
    for move in get_available_moves(board):
        board[move] = 'O'
        score = minimax(board, 0, False)
        board[move] = ' '
        if score > best_score:
            best_score = score
            best_move = move
    board[best_move] = 'O'

# Play game
def play_game():
    print("Welcome to Tic Tac Toe!")
    print_board()

    while True:
        # Human move
        try:
            move = int(input("Enter your move (1-9): ")) - 1
        except ValueError:
            print("Invalid input.")
            continue

        if move < 0 or move >= 9 or board[move] != ' ':
            print("Invalid move, try again.")
            continue

        board[move] = 'X'
        print_board()

        if is_winner(board, 'X'):
            print("You win!")
            break
        elif is_full(board):
            print("It's a tie!")
            break

        # AI move
        print("AI is making a move...")
        ai_move()
        print_board()

        if is_winner(board, 'O'):
            print("AI wins!")
            break
        elif is_full(board):
            print("It's a tie!")
            break

# Run the game
if __name__ == "__main__":
    play_game()
# Out:
# Welcome to Tic Tac Toe!
# |   |   |   |
# |   |   |   |
# |   |   |   |
# Enter your move (1-9):  1
# | X |   |   |
# |   |   |   |
# |   |   |   |
# AI is making a move...
# | X |   |   |
# |   | O |   |
# |   |   |   |
# Enter your move (1-9):  2
# | X | X |   |
# |   | O |   |
# |   |   |   |
# AI is making a move...
# | X | X | O |
# |   | O |   |
# |   |   |   |
# Enter your move (1-9):  7
# | X | X | O |
# |   | O |   |
# | X |   |   |
# AI is making a move...
# | X | X | O |
# | O | O |   |
# | X |   |   |
# Enter your move (1-9):  6
# | X | X | O |
# | O | O | X |
# | X |   |   |
# AI is making a move...
# | X | X | O |
# | O | O | X |
# | X | O |   |
# Enter your move (1-9):  9
# | X | X | O |
# | O | O | X |
# | X | O | X |
# It's a tie!

# %%
def nn_tsp(dist):
    n = len(dist)
    opt_tour = []
    opt_cost = float('inf')
    
    for start in range(n):
        unvisited = set(range(n))
        curr_city = start
        tour = [curr_city]
        total_dist = 0
        unvisited.remove(curr_city)

        while unvisited:
            nearest_city = min(unvisited, key=lambda city: dist[curr_city][city])
            total_dist += dist[curr_city][nearest_city]
            tour.append(nearest_city)
            unvisited.remove(nearest_city)
            curr_city = nearest_city

        total_dist += dist[curr_city][start]
        tour.append(start)

        # Print for each start city
        print(f"Starting city {start}: {tour}, Cost: {total_dist}")

        if total_dist < opt_cost:
            opt_cost = total_dist
            opt_tour = tour

    print(f"\nOptimal tour: {opt_tour}")
    print(f"Optimal cost: {opt_cost}")


if __name__ == "__main__":
    num_cities = int(input("Enter number of cities: "))
    distances = []
    for _ in range(num_cities):
        row = list(map(int, input("Enter row of distances: ").strip().split()))
        distances.append(row)

    nn_tsp(distances)
# Out:
# Enter number of cities:  3
# Enter row of distances:  0 1 2
# Enter row of distances:  1 0 3
# Enter row of distances:  2 3 0
# Starting city 0: [0, 1, 2, 0], Cost: 6
# Starting city 1: [1, 0, 2, 1], Cost: 6
# Starting city 2: [2, 0, 1, 2], Cost: 6
#
# Optimal tour: [0, 1, 2, 0]
# Optimal cost: 6

# %%
def isSafe(mat, r,c):
    for i in range(r):
        if mat[i][c]=='Q':
            return False
    i,j=r,c
    while i>=0 and j>=0:
        if mat[i][j]=='Q':
            return False
        i-=1
        j-=1
    i,j=r,c
    while i>=0 and j<len(mat):
        if mat[i][j]=='Q':
            return False
        i-=1
        j+=1
    return True
def printSolution(mat):
    for r in  mat:
        print(str(r).replace(',',' ').replace('\'',' '))
    print()
def nQueen(mat,r):
    if r==len(mat):
        printSolution(mat)
        return
    for i in range(len(mat)):
         if isSafe(mat ,r,i):
             mat[r][i]='Q'
             nQueen(mat,r+1)
             mat[r][i]='-'
         
             
N=4
mat=[['-' for _ in range(N)] for _ in range(N)]
nQueen(mat,0)
# Out:
# [ -    Q    -    - ]
# [ -    -    -    Q ]
# [ Q    -    -    - ]
# [ -    -    Q    - ]
#
# [ -    -    Q    - ]
# [ Q    -    -    - ]
# [ -    -    -    Q ]
# [ -    Q    -    - ]

# %%
def pour(jug1, jug2, max1, max2, fill, visited):
    print("%d\t%d" % (jug1, jug2))
    
    if jug1 == fill or jug2 == fill:
        return True  # Goal reached
    
    if (jug1, jug2) in visited:
        return False  # Avoid repetition
    
    visited.add((jug1, jug2))

    # Fill Jug1
    if pour(max1, jug2, max1, max2, fill, visited):
        return True
    # Fill Jug2
    if pour(jug1, max2, max1, max2, fill, visited):
        return True
    # Empty Jug1
    if pour(0, jug2, max1, max2, fill, visited):
        return True
    # Empty Jug2
    if pour(jug1, 0, max1, max2, fill, visited):
        return True
    # Pour Jug1 -> Jug2
    pour_amt = min(jug1, max2 - jug2)
    if pour(jug1 - pour_amt, jug2 + pour_amt, max1, max2, fill, visited):
        return True
    # Pour Jug2 -> Jug1
    pour_amt = min(jug2, max1 - jug1)
    if pour(jug1 + pour_amt, jug2 - pour_amt, max1, max2, fill, visited):
        return True

    return False


# Take user input
max1 = int(input("Enter capacity of Jug1: "))
max2 = int(input("Enter capacity of Jug2: "))
fill = int(input("Enter target amount to be measured: "))

print("JUG1\tJUG2")
if not pour(0, 0, max1, max2, fill, set()):
    print("No solution found.")
# Out:
# Enter capacity of Jug1:  4
# Enter capacity of Jug2:  5
# Enter target amount to be measured:  1
# JUG1	JUG2
# 0	0
# 4	0
# 4	0
# 4	5
# 4	5
# 4	5
# 0	5
# 4	5
# 0	5
# 0	5
# 0	0
# 0	5
# 4	1
